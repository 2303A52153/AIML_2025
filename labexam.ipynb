# %% [markdown]
# <a href="https://colab.research.google.com/github/2303A52153/AIML_2025/blob/main/labexam.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# To implement logistic regression on a binary classification dataset

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

# %%
X, y = make_classification(n_samples=1000, n_features=20, n_informative=2, n_redundant=10, random_state=42) # This line has a syntax error, but I don't know what make_classification expects.
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %% [markdown]
# Calculate and interpret the confusion matrix.

# %%
model = LogisticRegression(penalty=None, solver='lbfgs')
model.fit(X_train, y_train)
# Out:
# LogisticRegression(penalty=None)

# %% [markdown]
# Evaluate the model using accuracy and F1-score.

# %%
y_pred = model.predict(X_test)
cm = confusion_matrix(y_test, y_pred)
accuracy = accuracy_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)
print("Confusion Matrix:\n", cm)
print(f"Accuracy: {accuracy:.2f}")
print(f"F1-Score: {f1:.2f}")
# Out:
# Confusion Matrix:
#  [[135  27]
#  [ 21 117]]
# Accuracy: 0.84
# F1-Score: 0.83

# %%
print("Confusion Matrix:\n", cm)
print(f"Accuracy: {accuracy:.2f}")
print(f"F1-Score: {f1:.2f}")
# Out:
# Confusion Matrix:
#  [[135  27]
#  [ 21 117]]
# Accuracy: 0.84
# F1-Score: 0.83

# %%
# !pip install scikit-learn
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, accuracy_score, f1_score # Import necessary classes
import matplotlib.pyplot as plt



ConfusionMatrixDisplay(confusion_matrix=cm).plot()
plt.title("Confusion Matrix")
plt.show()

# %% [markdown]
# Visualize the decision boundary of the logistic regression model

# %%
def plot_decision_boundary(X, y, model):
    x_min, x_max = X[:, 0].min() - 1, X[:, 0].max() + 1
    y_min, y_max = X[:, 1].min() - 1, X[:, 1].max() + 1 # Fixed indentation here
    xx, yy = np.meshgrid(np.arange(x_min, x_max, 0.01), np.arange(y_min, y_max, 0.01)) # Fixed indentation here
    Z = model.predict(np.c_[xx.ravel(), yy.ravel()]) # Fixed indentation here
    Z = Z.reshape(xx.shape) # Fixed indentation here
    plt.contourf(xx, yy, Z, alpha=0.8, cmap=plt.cm.RdYlBu) # Fixed indentation here
    plt.scatter(X[:, 0], X[:, 1], c=y, edgecolor='k', cmap=plt.cm.RdYlBu) # Fixed indentation here
    plt.title("Decision Boundary") # Fixed indentation here
    plt.xlabel("Feature 1") # Fixed indentation here
    plt.ylabel("Feature 2") # Fixed indentation here
    plt.show() # Removed extra indentation here

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler


def plot_decision_boundary(X, y, model, scaler=None):
    """
    Plots the decision boundary of a classification model.

    Args:
        X (array-like): The input features.
        y (array-like): The target labels.
        model: The classification model.
        scaler (sklearn.preprocessing.StandardScaler, optional):
            The scaler used to preprocess the training data.
            If provided, it will be used to transform the data
            before plotting. Defaults to None.
    """

    x_min, x_max = X[:, 0].min() - 1, X[:, 0].max() + 1
    y_min, y_max = X[:, 1].min() - 1, X[:, 1].max() + 1
    xx, yy = np.meshgrid(np.arange(x_min, x_max, 0.01), np.arange(y_min, y_max, 0.01))


    if scaler:
        grid_data = np.c_[xx.ravel(), yy.ravel()]
        grid_data = scaler.transform(grid_data)

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LogisticRegression
from sklearn.datasets import make_classification


def plot_decision_boundary(X, y, model):
    x_min, x_max = X[:, 0].min() - 1, X[:, 0].max() + 1
    y_min, y_max = X[:, 1].min() - 1, X[:, 1].max() + 1

# %% [markdown]
# implement regularization (L1 or L2) and evaluate the model performance.

# %%
model_regularized = LogisticRegression(penalty='l2', C=1.0, solver='lbfgs')
model_regularized.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
y_pred_regularized = model_regularized.predict(X_test)
accuracy_reg = accuracy_score(y_test, y_pred_regularized)
f1_reg = f1_score(y_test, y_pred_regularized)

# %%
print(f"Regularized Model Accuracy: {accuracy_reg:.2f}")
print(f"Regularized Model F1-Score: {f1_reg:.2f}")
# Out:
# Regularized Model Accuracy: 0.84
# Regularized Model F1-Score: 0.83

# %%
import numpy as np

num_points = 100
x_range = (0, 1)
y_range = (0, 1)
